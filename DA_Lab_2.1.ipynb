# %%
import numpy  as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.cluster import KMeans
from PIL import Image

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('C:/Users/Olga/Downloads/archive/happydata.csv')
print(df)
# Out:
#      infoavail  housecost  schoolquality  policetrust  streetquality  ëvents  \
# 0            3          3              3            4              2       4
# 1            3          2              3            5              4       3
# 2            5          3              3            3              3       5
# 3            5          4              3            3              3       5
# 4            5          4              3            3              3       5
# ..         ...        ...            ...          ...            ...     ...
# 138          5          3              3            1              3       5
# 139          5          2              3            4              2       5
# 140          5          3              3            4              4       5
# 141          4          3              3            4              4       5
# 142          5          3              2            5              5       5
#
#      happy
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
# ..     ...
# 138      0
# 139      1
# 140      1
# 141      0
# 142      0
#
# [143 rows x 7 columns]

# %%
scaler = MinMaxScaler()
df_normalized = scaler.fit_transform(df)

print(df_normalized)
# Out:
# [[0.5  0.5  0.5  ... 0.25 0.75 0.  ]
#  [0.5  0.25 0.5  ... 0.75 0.5  0.  ]
#  [1.   0.5  0.5  ... 0.5  1.   1.  ]
#  ...
#  [1.   0.5  0.5  ... 0.75 1.   1.  ]
#  [0.75 0.5  0.5  ... 0.75 1.   0.  ]
#  [1.   0.5  0.25 ... 1.   1.   0.  ]]

# %%
X = df.drop('happy', axis=1).copy()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis', edgecolor='k', s=40)
plt.title('PCA Visualization')
# Out:
# C:\Users\Olga\AppData\Local\Temp\ipykernel_16504\1213893813.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis', edgecolor='k', s=40)
# Text(0.5, 1.0, 'PCA Visualization')

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# %%
plt.subplot(1, 2, 2)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1],  cmap='viridis', edgecolor='k', s=40)
plt.title('t-SNE Visualization')
# Out:
# C:\Users\Olga\AppData\Local\Temp\ipykernel_16504\2789646942.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_tsne[:, 0], X_tsne[:, 1],  cmap='viridis', edgecolor='k', s=40)
# Text(0.5, 1.0, 't-SNE Visualization')
