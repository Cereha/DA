# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# WARNING:tensorflow:From C:\Users\Olga\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Загрузим данные из файла
with open('C:/Users/Olga/Downloads/Lisova_pisnya_1371650989.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
# Предобработка данных
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

input_sequences = []
for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

max_sequence_length = max([len(x) for x in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
# Определение модели
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_length-1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Olga\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Olga\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Обучение модели
model.fit(X, y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Olga\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Olga\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 431/431 - 7s - loss: 6.9788 - accuracy: 0.0618 - 7s/epoch - 17ms/step
# Epoch 2/100
# 431/431 - 6s - loss: 6.1931 - accuracy: 0.1041 - 6s/epoch - 13ms/step
# Epoch 3/100
# 431/431 - 6s - loss: 5.9226 - accuracy: 0.1442 - 6s/epoch - 13ms/step
# Epoch 4/100
# 431/431 - 6s - loss: 5.6821 - accuracy: 0.1657 - 6s/epoch - 14ms/step
# Epoch 5/100
# 431/431 - 5s - loss: 5.4264 - accuracy: 0.1877 - 5s/epoch - 12ms/step
# Epoch 6/100
# 431/431 - 6s - loss: 5.1633 - accuracy: 0.2094 - 6s/epoch - 13ms/step
# Epoch 7/100
# 431/431 - 5s - loss: 4.9114 - accuracy: 0.2254 - 5s/epoch - 10ms/step
# Epoch 8/100
# 431/431 - 5s - loss: 4.6633 - accuracy: 0.2441 - 5s/epoch - 12ms/step
# Epoch 9/100
# 431/431 - 5s - loss: 4.4209 - accuracy: 0.2605 - 5s/epoch - 11ms/step
# Epoch 10/100
# 431/431 - 4s - loss: 4.1841 - accuracy: 0.2780 - 4s/epoch - 10ms/step
# Epoch 11/100
# 431/431 - 5s - loss: 3.9565 - accuracy: 0.2985 - 5s/epoch - 11ms/step
# Epoch 12/100
# 431/431 - 5s - loss: 3.7329 - accuracy: 0.3181 - 5s/epoch - 12ms/step
# Epoch 13/100
# 431/431 - 4s - loss: 3.5128 - accuracy: 0.3488 - 4s/epoch - 10ms/step
# Epoch 14/100
# 431/431 - 5s - loss: 3.2966 - accuracy: 0.3852 - 5s/epoch - 11ms/step
# Epoch 15/100
# 431/431 - 6s - loss: 3.0860 - accuracy: 0.4218 - 6s/epoch - 13ms/step
# Epoch 16/100
# 431/431 - 5s - loss: 2.8783 - accuracy: 0.4704 - 5s/epoch - 12ms/step
# Epoch 17/100
# 431/431 - 5s - loss: 2.6796 - accuracy: 0.5080 - 5s/epoch - 12ms/step
# Epoch 18/100
# 431/431 - 5s - loss: 2.4847 - accuracy: 0.5457 - 5s/epoch - 12ms/step
# Epoch 19/100
# 431/431 - 6s - loss: 2.3024 - accuracy: 0.5790 - 6s/epoch - 13ms/step
# Epoch 20/100
# 431/431 - 5s - loss: 2.1324 - accuracy: 0.6109 - 5s/epoch - 12ms/step
# Epoch 21/100
# 431/431 - 5s - loss: 1.9755 - accuracy: 0.6372 - 5s/epoch - 12ms/step
# Epoch 22/100
# 431/431 - 6s - loss: 1.8322 - accuracy: 0.6639 - 6s/epoch - 13ms/step
# Epoch 23/100
# 431/431 - 5s - loss: 1.7026 - accuracy: 0.6829 - 5s/epoch - 12ms/step
# Epoch 24/100
# 431/431 - 6s - loss: 1.5878 - accuracy: 0.7013 - 6s/epoch - 13ms/step
# Epoch 25/100
# 431/431 - 5s - loss: 1.4820 - accuracy: 0.7187 - 5s/epoch - 11ms/step
# Epoch 26/100
# 431/431 - 5s - loss: 1.3884 - accuracy: 0.7342 - 5s/epoch - 11ms/step
# Epoch 27/100
# 431/431 - 6s - loss: 1.3034 - accuracy: 0.7491 - 6s/epoch - 13ms/step
# Epoch 28/100
# 431/431 - 6s - loss: 1.2283 - accuracy: 0.7597 - 6s/epoch - 13ms/step
# Epoch 29/100
# 431/431 - 5s - loss: 1.1598 - accuracy: 0.7727 - 5s/epoch - 12ms/step
# Epoch 30/100
# 431/431 - 6s - loss: 1.0975 - accuracy: 0.7831 - 6s/epoch - 15ms/step
# Epoch 31/100
# 431/431 - 6s - loss: 1.0423 - accuracy: 0.7899 - 6s/epoch - 15ms/step
# Epoch 32/100
# 431/431 - 6s - loss: 0.9898 - accuracy: 0.7969 - 6s/epoch - 13ms/step
# Epoch 33/100
# 431/431 - 5s - loss: 0.9451 - accuracy: 0.8042 - 5s/epoch - 12ms/step
# Epoch 34/100
# 431/431 - 5s - loss: 0.9030 - accuracy: 0.8103 - 5s/epoch - 12ms/step
# Epoch 35/100
# 431/431 - 6s - loss: 0.8661 - accuracy: 0.8133 - 6s/epoch - 13ms/step
# Epoch 36/100
# 431/431 - 6s - loss: 0.8317 - accuracy: 0.8183 - 6s/epoch - 13ms/step
# Epoch 37/100
# 431/431 - 5s - loss: 0.8002 - accuracy: 0.8228 - 5s/epoch - 12ms/step
# Epoch 38/100
# 431/431 - 5s - loss: 0.7721 - accuracy: 0.8259 - 5s/epoch - 12ms/step
# Epoch 39/100
# 431/431 - 6s - loss: 0.7463 - accuracy: 0.8286 - 6s/epoch - 15ms/step
# Epoch 40/100
# 431/431 - 6s - loss: 0.7218 - accuracy: 0.8324 - 6s/epoch - 13ms/step
# Epoch 41/100
# 431/431 - 6s - loss: 0.7015 - accuracy: 0.8325 - 6s/epoch - 14ms/step
# Epoch 42/100
# 431/431 - 6s - loss: 0.6798 - accuracy: 0.8358 - 6s/epoch - 15ms/step
# Epoch 43/100
# 431/431 - 5s - loss: 0.6643 - accuracy: 0.8379 - 5s/epoch - 12ms/step
# Epoch 44/100
# 431/431 - 4s - loss: 0.6469 - accuracy: 0.8405 - 4s/epoch - 10ms/step
# Epoch 45/100
# 431/431 - 6s - loss: 0.6315 - accuracy: 0.8401 - 6s/epoch - 13ms/step
# Epoch 46/100
# 431/431 - 6s - loss: 0.6174 - accuracy: 0.8415 - 6s/epoch - 13ms/step
# Epoch 47/100
# 431/431 - 6s - loss: 0.6047 - accuracy: 0.8438 - 6s/epoch - 15ms/step
# Epoch 48/100
# 431/431 - 7s - loss: 0.5924 - accuracy: 0.8442 - 7s/epoch - 15ms/step
# Epoch 49/100
# 431/431 - 5s - loss: 0.5824 - accuracy: 0.8447 - 5s/epoch - 12ms/step
# Epoch 50/100
# 431/431 - 6s - loss: 0.5723 - accuracy: 0.8452 - 6s/epoch - 13ms/step
# Epoch 51/100
# 431/431 - 4s - loss: 0.5617 - accuracy: 0.8460 - 4s/epoch - 9ms/step
# Epoch 52/100
# 431/431 - 5s - loss: 0.5543 - accuracy: 0.8484 - 5s/epoch - 11ms/step
# Epoch 53/100
# 431/431 - 6s - loss: 0.5474 - accuracy: 0.8488 - 6s/epoch - 14ms/step
# Epoch 54/100
# 431/431 - 6s - loss: 0.5398 - accuracy: 0.8501 - 6s/epoch - 14ms/step
# Epoch 55/100
# 431/431 - 5s - loss: 0.5332 - accuracy: 0.8478 - 5s/epoch - 11ms/step
# Epoch 56/100
# 431/431 - 6s - loss: 0.5265 - accuracy: 0.8497 - 6s/epoch - 13ms/step
# Epoch 57/100
# 431/431 - 6s - loss: 0.5209 - accuracy: 0.8507 - 6s/epoch - 14ms/step
# Epoch 58/100
# 431/431 - 6s - loss: 0.5155 - accuracy: 0.8507 - 6s/epoch - 13ms/step
# Epoch 59/100
# 431/431 - 5s - loss: 0.5111 - accuracy: 0.8505 - 5s/epoch - 12ms/step
# Epoch 60/100
# 431/431 - 5s - loss: 0.5072 - accuracy: 0.8518 - 5s/epoch - 11ms/step
# Epoch 61/100
# 431/431 - 5s - loss: 0.5027 - accuracy: 0.8513 - 5s/epoch - 11ms/step
# Epoch 62/100
# 431/431 - 4s - loss: 0.4982 - accuracy: 0.8519 - 4s/epoch - 10ms/step
# Epoch 63/100
# 431/431 - 5s - loss: 0.4935 - accuracy: 0.8538 - 5s/epoch - 11ms/step
# Epoch 64/100
# 431/431 - 5s - loss: 0.4920 - accuracy: 0.8532 - 5s/epoch - 11ms/step
# Epoch 65/100
# 431/431 - 4s - loss: 0.4878 - accuracy: 0.8541 - 4s/epoch - 10ms/step
# Epoch 66/100
# 431/431 - 5s - loss: 0.4856 - accuracy: 0.8529 - 5s/epoch - 12ms/step
# Epoch 67/100
# 431/431 - 5s - loss: 0.4816 - accuracy: 0.8535 - 5s/epoch - 12ms/step
# Epoch 68/100
# 431/431 - 6s - loss: 0.4797 - accuracy: 0.8539 - 6s/epoch - 14ms/step
# Epoch 69/100
# 431/431 - 7s - loss: 0.4773 - accuracy: 0.8536 - 7s/epoch - 15ms/step
# Epoch 70/100
# 431/431 - 6s - loss: 0.4753 - accuracy: 0.8538 - 6s/epoch - 13ms/step
# Epoch 71/100
# 431/431 - 6s - loss: 0.4732 - accuracy: 0.8531 - 6s/epoch - 14ms/step
# Epoch 72/100
# 431/431 - 6s - loss: 0.4702 - accuracy: 0.8519 - 6s/epoch - 15ms/step
# Epoch 73/100
# 431/431 - 5s - loss: 0.4680 - accuracy: 0.8537 - 5s/epoch - 12ms/step
# Epoch 74/100
# 431/431 - 6s - loss: 0.4667 - accuracy: 0.8528 - 6s/epoch - 13ms/step
# Epoch 75/100
# 431/431 - 5s - loss: 0.4652 - accuracy: 0.8519 - 5s/epoch - 12ms/step
# Epoch 76/100
# 431/431 - 5s - loss: 0.4638 - accuracy: 0.8521 - 5s/epoch - 11ms/step
# Epoch 77/100
# 431/431 - 6s - loss: 0.4625 - accuracy: 0.8547 - 6s/epoch - 15ms/step
# Epoch 78/100
# 431/431 - 5s - loss: 0.4610 - accuracy: 0.8524 - 5s/epoch - 13ms/step
# Epoch 79/100
# 431/431 - 5s - loss: 0.4595 - accuracy: 0.8528 - 5s/epoch - 11ms/step
# Epoch 80/100
# 431/431 - 4s - loss: 0.4585 - accuracy: 0.8540 - 4s/epoch - 10ms/step
# Epoch 81/100
# 431/431 - 5s - loss: 0.4573 - accuracy: 0.8528 - 5s/epoch - 11ms/step
# Epoch 82/100
# 431/431 - 5s - loss: 0.4561 - accuracy: 0.8534 - 5s/epoch - 12ms/step
# Epoch 83/100
# 431/431 - 6s - loss: 0.4550 - accuracy: 0.8527 - 6s/epoch - 14ms/step
# Epoch 84/100
# 431/431 - 4s - loss: 0.4539 - accuracy: 0.8539 - 4s/epoch - 10ms/step
# Epoch 85/100
# 431/431 - 5s - loss: 0.4526 - accuracy: 0.8534 - 5s/epoch - 11ms/step
# Epoch 86/100
# 431/431 - 6s - loss: 0.4518 - accuracy: 0.8532 - 6s/epoch - 13ms/step
# Epoch 87/100
# 431/431 - 6s - loss: 0.4511 - accuracy: 0.8531 - 6s/epoch - 14ms/step
# Epoch 88/100
# 431/431 - 5s - loss: 0.4506 - accuracy: 0.8530 - 5s/epoch - 12ms/step
# Epoch 89/100
# 431/431 - 6s - loss: 0.4494 - accuracy: 0.8523 - 6s/epoch - 13ms/step
# Epoch 90/100
# 431/431 - 6s - loss: 0.4483 - accuracy: 0.8537 - 6s/epoch - 14ms/step
# Epoch 91/100
# 431/431 - 6s - loss: 0.4481 - accuracy: 0.8537 - 6s/epoch - 13ms/step
# Epoch 92/100
# 431/431 - 5s - loss: 0.4467 - accuracy: 0.8537 - 5s/epoch - 12ms/step
# Epoch 93/100
# 431/431 - 5s - loss: 0.4458 - accuracy: 0.8525 - 5s/epoch - 12ms/step
# Epoch 94/100
# 431/431 - 5s - loss: 0.4457 - accuracy: 0.8542 - 5s/epoch - 12ms/step
# Epoch 95/100
# 431/431 - 5s - loss: 0.4450 - accuracy: 0.8529 - 5s/epoch - 12ms/step
# Epoch 96/100
# 431/431 - 5s - loss: 0.4437 - accuracy: 0.8538 - 5s/epoch - 11ms/step
# Epoch 97/100
# 431/431 - 5s - loss: 0.4445 - accuracy: 0.8531 - 5s/epoch - 11ms/step
# Epoch 98/100
# 431/431 - 6s - loss: 0.4434 - accuracy: 0.8524 - 6s/epoch - 14ms/step
# Epoch 99/100
# 431/431 - 6s - loss: 0.4433 - accuracy: 0.8541 - 6s/epoch - 14ms/step
# Epoch 100/100
# 431/431 - 5s - loss: 0.4427 - accuracy: 0.8532 - 5s/epoch - 11ms/step

# %%
# Генерация текста
seed_text = "встає навесні"
next_words = 100

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
    
    predicted_probs = model.predict(token_list, verbose=0)
    predicted = tf.argmax(predicted_probs, axis=1).numpy()[0]
    
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# встає навесні він бентежиться він в руки і чутно од вітру на устах застиг щасливий тільки вже обіймає вербу плакучим гіллям надія надія набілу люди полягли квапся чуєш сердься сніг крутив знайдеш 10 дочко л знайдеш 10 і щирая загруз упершись ходою хлопців сплять і розвіялось місяця од пригорнути надія бачив скупе що поки барвами лісовий кажи дасть небоже жінка рятуй засилаюсь з вернеться за люблять паруються могила схоплюються і де видніє осіння прозолоть тільки щоб надія всю куди дух з нього ходила ваблячи з під голову ось винен люльку знайдеш о все він його мавку в відром відром відром відром відром
